# %% [markdown]
# # Evaluación de traducción de imágenes

# %% [markdown]
# ## Dependencias

# %%
# Jupyter widgets
# !pip install ipywidgets
# Install matplotlib for plotting
# !pip install matplotlib
# Install nltk for text processing
# !pip install nltk
# Install sacreBLEU for evaluation
# !pip install sacreBLEU
# Install transformers for model support
# !pip install transformers accelerate torch bitsandbytes sentencepiece huggingface_hub datasets
# Install my latest version of onnxTR
# For CPU support
#!pip install "onnxtr[cpu]"
# For GPU support
# !pip install "onnxtr[gpu]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /home/blai/.local/lib/python3.10/site-packages (8.1.7)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/blai/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: traitlets>=4.3.1 in /home/blai/.local/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/blai/.local/lib/python3.10/site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/blai/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: comm>=0.1.3 in /home/blai/.local/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: matplotlib-inline in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: typing_extensions>=4.6 in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.14.0)
# Requirement already satisfied: exceptiongroup in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.3.0)
# Requirement already satisfied: stack_data in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: pygments>=2.4.0 in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: decorator in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pexpect>4.3 in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: jedi>=0.16 in /home/blai/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/blai/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/blai/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/blai/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: asttokens>=2.1.0 in /home/blai/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/blai/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /home/blai/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/blai/.local/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/blai/.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/blai/.local/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /home/blai/.local/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: numpy>=1.23 in /home/blai/.local/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: pillow>=8 in /home/blai/.local/lib/python3.10/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/blai/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/blai/.local/lib/python3.10/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: cycler>=0.10 in /home/blai/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/blai/.local/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: joblib in /home/blai/.local/lib/python3.10/site-packages (from nltk) (1.5.1)
# Requirement already satisfied: click in /home/blai/.local/lib/python3.10/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/blai/.local/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/blai/.local/lib/python3.10/site-packages (from nltk) (4.67.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sacreBLEU in /home/blai/.local/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: tabulate>=0.8.9 in /home/blai/.local/lib/python3.10/site-packages (from sacreBLEU) (0.9.0)
# Requirement already satisfied: regex in /home/blai/.local/lib/python3.10/site-packages (from sacreBLEU) (2024.11.6)
# Requirement already satisfied: numpy>=1.17 in /home/blai/.local/lib/python3.10/site-packages (from sacreBLEU) (2.2.6)
# Requirement already satisfied: colorama in /home/blai/.local/lib/python3.10/site-packages (from sacreBLEU) (0.4.6)
# Requirement already satisfied: lxml in /home/blai/.local/lib/python3.10/site-packages (from sacreBLEU) (6.0.0)
# Requirement already satisfied: portalocker in /home/blai/.local/lib/python3.10/site-packages (from sacreBLEU) (3.2.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/blai/.local/lib/python3.10/site-packages (4.53.0)
# Requirement already satisfied: accelerate in /home/blai/.local/lib/python3.10/site-packages (1.8.1)
# Requirement already satisfied: torch in /home/blai/.local/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: bitsandbytes in /home/blai/.local/lib/python3.10/site-packages (0.46.0)
# Requirement already satisfied: sentencepiece in /home/blai/.local/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: huggingface_hub in /home/blai/.local/lib/python3.10/site-packages (0.33.0)
# Requirement already satisfied: datasets in /home/blai/.local/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/blai/.local/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: numpy>=1.17 in /home/blai/.local/lib/python3.10/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: filelock in /home/blai/.local/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: requests in /home/blai/.local/lib/python3.10/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/blai/.local/lib/python3.10/site-packages (from transformers) (0.21.2)
# Requirement already satisfied: tqdm>=4.27 in /home/blai/.local/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: packaging>=20.0 in /home/blai/.local/lib/python3.10/site-packages (from transformers) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/blai/.local/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /home/blai/.local/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: psutil in /home/blai/.local/lib/python3.10/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/blai/.local/lib/python3.10/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/blai/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/blai/.local/lib/python3.10/site-packages (from torch) (4.14.0)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/blai/.local/lib/python3.10/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/blai/.local/lib/python3.10/site-packages (from torch) (12.6.85)
# Requirement already satisfied: fsspec in /home/blai/.local/lib/python3.10/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: networkx in /home/blai/.local/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/blai/.local/lib/python3.10/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/blai/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: sympy>=1.13.3 in /home/blai/.local/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/blai/.local/lib/python3.10/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/blai/.local/lib/python3.10/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/blai/.local/lib/python3.10/site-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/blai/.local/lib/python3.10/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: jinja2 in /home/blai/.local/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/blai/.local/lib/python3.10/site-packages (from torch) (3.3.1)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/blai/.local/lib/python3.10/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/blai/.local/lib/python3.10/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/blai/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/blai/.local/lib/python3.10/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/lib/python3/dist-packages (from triton==3.3.1->torch) (59.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/blai/.local/lib/python3.10/site-packages (from huggingface_hub) (1.1.5)
# Requirement already satisfied: multiprocess<0.70.17 in /home/blai/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: xxhash in /home/blai/.local/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/blai/.local/lib/python3.10/site-packages (from datasets) (20.0.0)
# Requirement already satisfied: pandas in /home/blai/.local/lib/python3.10/site-packages (from datasets) (2.3.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/blai/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/blai/.local/lib/python3.10/site-packages (from fsspec->torch) (3.12.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/blai/.local/lib/python3.10/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/blai/.local/lib/python3.10/site-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/blai/.local/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/blai/.local/lib/python3.10/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/blai/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/blai/.local/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/blai/.local/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/blai/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/blai/.local/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/blai/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch) (2.6.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/blai/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch) (0.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/blai/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch) (6.6.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/blai/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/blai/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch) (25.3.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/blai/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch) (5.0.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/blai/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch) (1.20.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/blai/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch) (1.7.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: onnxtr[gpu] in /home/blai/.local/lib/python3.10/site-packages (0.7.1)
# Requirement already satisfied: Pillow>=9.2.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (11.2.1)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (1.15.3)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (2.2.6)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (1.0.9)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.23.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (0.33.0)
# Requirement already satisfied: anyascii>=0.3.2 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (0.3.3)
# Requirement already satisfied: tqdm>=4.30.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (4.67.1)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.11.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (4.30.1)
# Requirement already satisfied: pyclipper<2.0.0,>=1.2.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (1.3.0.post6)
# Requirement already satisfied: defusedxml>=0.7.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (0.7.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (3.13.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (4.11.0.86)
# Requirement already satisfied: onnxruntime-gpu>=1.18.0 in /home/blai/.local/lib/python3.10/site-packages (from onnxtr[gpu]) (1.22.0)
# Requirement already satisfied: packaging>=20.9 in /home/blai/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/blai/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/blai/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (4.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/blai/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/blai/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (1.1.5)
# Requirement already satisfied: filelock in /home/blai/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (3.18.0)
# Requirement already satisfied: requests in /home/blai/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (2.32.4)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from langdetect<2.0.0,>=1.0.9->onnxtr[gpu]) (1.16.0)
# Requirement already satisfied: protobuf in /home/blai/.local/lib/python3.10/site-packages (from onnxruntime-gpu>=1.18.0->onnxtr[gpu]) (6.31.1)
# Requirement already satisfied: flatbuffers in /home/blai/.local/lib/python3.10/site-packages (from onnxruntime-gpu>=1.18.0->onnxtr[gpu]) (25.2.10)
# Requirement already satisfied: coloredlogs in /home/blai/.local/lib/python3.10/site-packages (from onnxruntime-gpu>=1.18.0->onnxtr[gpu]) (15.0.1)
# Requirement already satisfied: sympy in /home/blai/.local/lib/python3.10/site-packages (from onnxruntime-gpu>=1.18.0->onnxtr[gpu]) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/blai/.local/lib/python3.10/site-packages (from coloredlogs->onnxruntime-gpu>=1.18.0->onnxtr[gpu]) (10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/blai/.local/lib/python3.10/site-packages (from requests->huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/blai/.local/lib/python3.10/site-packages (from requests->huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/blai/.local/lib/python3.10/site-packages (from requests->huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/blai/.local/lib/python3.10/site-packages (from requests->huggingface-hub<1.0.0,>=0.23.0->onnxtr[gpu]) (2025.6.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/blai/.local/lib/python3.10/site-packages (from sympy->onnxruntime-gpu>=1.18.0->onnxtr[gpu]) (1.3.0)

# %% [markdown]
# ## Hugging Face login

# %%
from huggingface_hub import login

# Login to Hugging Face Hub
# login()

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Import docTR libraries
from onnxtr.io import DocumentFile
from onnxtr.models import ocr_predictor

# Import the MTEvaluation class from my TFG
from mt_evaluation import MTEvaluation

# %% [markdown]
# ## Datos

# %%
# Obtain the data

# Set language pairs
source_lang = 'en'
target_lang = 'de'

# Main directory of the dataset
DATASET_DIR = '/home/blai/TFM/Datasets/IWSLT/'

# Set the path to the corpus files
IMAGES_EN = DATASET_DIR + 'iwslt14.de-en-images/test_en/'
IMAGES_DE = DATASET_DIR + 'iwslt14.de-en-images/test_de/'
CORPUS_EN = DATASET_DIR + 'iwslt14.de-en/test.en'
CORPUS_DE = DATASET_DIR + 'iwslt14.de-en/test.de'

# Engines to evaluate
engines = {
    'euroLLM': 'utter-project/EuroLLM-1.7B',
    'LLaMA': 'meta-llama/Llama-3.2-1B-Instruct',
    'M2M100': 'facebook/m2m100_1.2B',
}

# Create an instance of the MTEvaluation class
mt_eval = MTEvaluation(source_lang, target_lang, engines=engines, source=CORPUS_EN, references=CORPUS_DE)

# %% [markdown]
# ## Extracción del texto de las imagenes

# %%
# Instantiate a pretrained model
predictor = ocr_predictor('fast_base', # Text Detection
                          'crnn_vgg16_bn', # Text Recognition
                          # Document related parameters
                          assume_straight_pages=False,  # set to `False` if the pages are not straight (rotation, perspective, etc.) (default: True)
                          straighten_pages=False,  # set to `True` if the pages should be straightened before final processing (default: False)
                          export_as_straight_boxes=False,  # set to `True` if the boxes should be exported as if the pages were straight (default: False)
                          # Preprocessing related parameters
                          preserve_aspect_ratio=True,  # set to `False` if the aspect ratio should not be preserved (default: True)
                          symmetric_pad=True,  # set to `False` to disable symmetric padding (default: True)
                          # Additional parameters - meta information
                          detect_orientation=False,  # set to `True` if the orientation of the pages should be detected (default: False)
                          detect_language=False, # set to `True` if the language of the pages should be detected (default: False)
                          # Orientation specific parameters in combination with `assume_straight_pages=False` and/or `straighten_pages=True`
                          disable_crop_orientation=False,  # set to `True` if the crop orientation classification should be disabled (default: False)
                          disable_page_orientation=False,  # set to `True` if the general page orientation classification should be disabled (default: False)
                          # DocumentBuilder specific parameters
                          resolve_lines=True,  # whether words should be automatically grouped into lines (default: True)
                          resolve_blocks=False,  # whether lines should be automatically grouped into blocks (default: False)
                          paragraph_break=0.035,  # relative length of the minimum space separating paragraphs (default: 0.035)
                          )

# %%
from random import shuffle
import os

# Number the images to evaluate
N = 100

# Makea list of the number of images to evaluate
def get_image_numbers(n):
    file_list = os.listdir(IMAGES_EN)
    shuffle(file_list)
    image_numbers = []
    for i, filename in enumerate(file_list):
        if i >= n:
            break
        if filename.endswith('.jpg') or filename.endswith('.png'):
            image_numbers.append(filename.split('.')[0])
    return image_numbers

numbers = get_image_numbers(N)

# Make a list of image paths and save it in a dict, where the keys are the image names and the values are the image paths
def get_image_paths(image_dir, numbers):
    image_paths = {}
    file_list = os.listdir(image_dir)
    for filename in file_list:
        if filename.split('.')[0] in numbers:
            image_paths[filename.split('.')[0]] = os.path.join(image_dir, filename)
    return image_paths

images_paths_en = {}
image_paths_en = get_image_paths(IMAGES_EN, numbers)
print(f"Selected {len(image_paths_en)} images from {IMAGES_EN}")

images_paths_de = {}
image_paths_de = get_image_paths(IMAGES_DE, numbers)
print(f"Selected {len(image_paths_de)} images from {IMAGES_DE}")

# Read the images and run OCR on them
images_en = DocumentFile.from_images([image_paths_en[name] for name in image_paths_en.keys()])
# Out:
# Selected 100 images from /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/
# Selected 100 images from /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_de/

# %%
import time

# Process the images with the OCR predictor
start_time = time.time()
results = predictor(images_en)
end_time = time.time()
print(f"Processed {len(results.pages)} images in {end_time - start_time:.2f} seconds.")

# Print the results of the first N images
i = 0
for n, page in zip(image_paths_en.keys(), results.pages):
    if i >= 10:
        break
    print(f"Image {n}: {image_paths_en[n]}")
    print("Text:", page.render().replace('\n', ' '))
    print()
    i += 1
# Out:
# Processed 100 images in 49.35 seconds.
# Image 4136: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/4136.jpg
# Text: in a certain sense, it's almost as if the old dream of michelangelo.
#
# Image 4105: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/4105.jpg
# Text: SO obviously this S! not all going to fit back ul my tiny suitcase.
#
# Image 1614: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/1614.jpg
# Text: in this way, every concert is a different concert.
#
# Image 5569: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/5569.jpg
# Text: this is the call center for the services and information line.
#
# Image 2019: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/2019.jpg
# Text: the spinning reserve has at least ten seconds to keep the network stable.
#
# Image 2567: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/2567.jpg
# Text: who's going to be sure?
#
# Image 2315: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/2315.jpg
# Text: i'm going to go ahead and select government.
#
# Image 846: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/846.jpg
# Text: SO here's another few people trying it out.
#
# Image 1015: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/1015.jpg
# Text: SO what are archaic models?
#
# Image 4246: /home/blai/TFM/Datasets/IWSLT/iwslt14.de-en-images/test_en/4246.jpg
# Text: this can be, u! our case, we want to use it for designing and doing a symbol.

# %% [markdown]
# ## Comprobar texto extraido con el del dataset

# %%
# Import necessary libraries for evaluation metrics
from sacrebleu.metrics.bleu import BLEU
from sacrebleu.metrics.chrf import CHRF
from sacrebleu.metrics.ter import TER

# Initialize evaluation metrics
bleu = BLEU()
chrf = CHRF()
ter = TER()

# Prepare the extracted sentences, source sentences and reference sentences for evaluation
extracted_sentences = []
source_sentences = []
reference_sentences = []

# Select from the extracted sentences, the i source sentences that correspond to the images
for i, (n, page) in enumerate(zip(image_paths_en.keys(), results.pages)):
    if i >= N:
        break
    # Get the corresponding sentence from the results
    extracted_sentences.append(page.render().replace('\n', ' '))
    # Get the corresponding sentence from the source corpus
    source_sentences.append(mt_eval.get_source()[int(n)])
    # Get the corresponding sentence from the reference corpus
    reference_sentences.append(mt_eval.get_references()[int(n)])

#  Compute the evaluation metrics
bleu = bleu.corpus_score(extracted_sentences, [source_sentences])
chrf = chrf.corpus_score(extracted_sentences, [source_sentences])
ter = ter.corpus_score(extracted_sentences, [source_sentences])

# Print the evaluation results
print(f"BLEU: {bleu.score:.2f}")
print(f"CHRF: {chrf.score:.2f}")
print(f"TER: {ter.score:.2f}")

# Set new source and reference sentences for the MTEvaluation class
mt_eval.set_source_from_list(extracted_sentences)
mt_eval.set_references_from_list(reference_sentences)
# Out:
# BLEU: 87.60
# CHRF: 95.95
# TER: 7.21

# %% [markdown]
# ## Traducción del texto extraido

# %%
# Translate the source sentences using the engines specified in the MTEvaluation class

mt_eval.translate(save=True, folder='translations')
# Out:
# Translating with 'euroLLM'
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Translation with 'euroLLM' done in 556.1833 seconds
# Translating with 'LLaMA'
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Translation with 'LLaMA' done in 959.8062 seconds
# Translating with 'M2M100'
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Translation with 'M2M100' done in 340.7204 seconds

# %%
# Print the translations
for engine, translations in mt_eval.mt.items():
    print(f"Translations for {engine}:")
    for i, translation in zip(image_paths_en.keys(), translations.segments()):
        print(f"Image {i}: {translation}")
    print()
# Out:
# Translations for euroLLM:
# Image 4136: in gewissem sinne ist es fast so, als ob der alte traum von michelangelo.
# Image 4105: So passt das S! natürlich nicht alles in meine kleine Koffer.
# Image 1614: So ist jedes Konzert ein anderes Konzert.
# Image 5569: Dies ist das Callcenter für die Dienstleistungen und Informationslinie.
# Image 2019: Die Spinnreserve hat mindestens zehn Sekunden Zeit, um das Netz stabil zu halten.
# Image 2567: Wer wird sich sicher sein?
# Image 2315: Ich werde vorgehen und den Regierungsausschuss auswählen.
# Image 846: SO hier sind noch ein paar Leute, die es ausprobieren.
# Image 1015: Also, was sind archaische Modelle?
# Image 4246: Dies kann, wie im Fall von u, sein, wir wollen es für das Entwerfen und das Ausführen eines Symbols verwenden.
# Image 1136: und das ist mir in den letzten sechs Monaten passiert.
# Image 4126: Wenn wir Städte festlegen, ist es eigentlich ein großer Deal.
# Image 6048: Du weißt, letztlich müssen wir alle Dinge glauben, die wir nicht gesehen haben.
# Image 4734: Der nächste war der beste Tag überhaupt.
# Image 4737: - wie Dinge, die anders sind.
# Image 4149: Hier sehen Sie die Stadt.
# Image 5530: Dies ist eine bescheidene kleine App.
# Image 3445: Wir haben 18 Jahre lang Würfel gespielt, seit 16 Jahren spielen wir Warcraft.
# Image 4929: Und hier ist ein wirklich, wirklich großer Nahaufnahme des kleinen Stückes Metall.
# Image 5133: Ihr wisst, dass es einen Trick gab, nicht wahr?
# Image 2283: Danke.
# Image 4099: Also gibt es keine Entschuldigung für uns alle hier in diesem Publikum.
# Image 6690: Es ist eine Frage der Freiheit gegen Kontrolle.
# Image 542: Also haben wir etwa 50 der Magnete beschädigt.
# Image 669: - doil sieht aus - - kann einen Song jetzt aufschreiben?
# Image 4698: Wie würden Sie Ihre Marke beschreiben?
# Image 1553: das können wir.
# Image 1301: Jeder hatte früher etwas Kuchen.
# Image 712: Sei nicht entmutigt.
# Image 1371: Das heißt, es gibt nicht zu viele von uns, wir sind einfach zu dumm, sehen Sie?
# Image 2971: Ich muss sagen, ich verstehe es nicht.
# Image 6405: andi - ging zurück zu meinem arbeit auf den wards.
# Image 2066: Also, ich habe angefangen zu spielen.
# Image 6469: jetzt 5 in beiden Fällen, habe ich sie nicht nach Hause geschickt und - denke nicht, dass es einen Unterschied in ihrer Pflege gab.
# Image 3025: und dann werde ich erklären, warum ich es erklärt habe.
# Image 504: Sonnenlicht und Co2 ist eine Methode...
# Image 5901: Sie war die Tochter von Menschen, die tatsächlich versklavt waren.
# Image 4295: SO ist jetzt völlig gelähmt.
# Image 1114: Dies ist ein Spiel für draußen.
# Image 331: Drittens: Erhöhung der Erwartungen.
# Image 4557: das ist die Konsequenz, der wir uns stellen müssen.
# Image 5689: und die, die so waren, begannen sich zu spalten und zu teilen.
# Image 5226: Es wurde fast 200 Millionen Mal in diesem Jahr gesehen.
# Image 9: und das ist eine Idee, wenn man darüber nachdenkt, kann dich nur mit Hoffnung füllen.
# Image 3402: Es gibt einen Ökonomen namens Edward Castronova.
# Image 5906: und sie drückte mich so fest - - konnte kaum atmen und dann ließ sie mich gehen.
# Image 5961: und das waren die Dinge, die sie dachte, dass wir uns zu verpflichten hatten.
# Image 5599: Es verband diese beiden Menschen.
# Image 5485: und wir haben eine ipad-anwendung gebaut.
# Image 3533: es ist Teil unserer Lebens.
# Image 2343: Ich - wuchs dn auf einer festen Diät von Science Fiction.
# Image 4637: Sie wollten absolut nichts mit diesem Projekt zu tun haben.
# Image 1411: Sie sehen?
# Image 4449: etwa einen Monat später, ich war bei einer Aufführung meiner Tochter - Erstklässlerin, nicht viel künstlerisches Talent...
# Image 2886: jetzt, / verstehe es. Ich verstehe es.
# Image 4714: in meiner verzerrten kleinen Industrie, das ist meine Marke.
# Image 5917: und - würde sie ansehen und ich würde lächeln, aber sie war sehr ernst.
# Image 3821: SO gehst du in das Spiel.s schließe die Schuhe.
# Image 27: machen wir es Kogi. 1I
# Image 1778: weil wir nicht ohne diese Lüge unser Leben leben können.
# Image 1027: Wie viele Türen hat die Wohnung, in der du wohnst?
# Image 2758: sie den Prozess managen, sie den Prozess verstehen.
# Image 1720: und auch alles, was sie heute in ihren Köpfen hätten!
# Image 5572: SO scott bekommt diese anruf.
# Image 1822: So sehen die Leute, wie die Seele funktioniert.
# Image 2784: Es gibt Schritt-für-Schritt-Anweisungen dazu.
# Image 4696: Ich muss mit dem Mann auf der Straße reden, mit den Leuten, die wie ich sind, die normalen Leute.
# Image 305: und 11 denken, dass es die Welt so aussehen lässt.
# Image 4830: Sie bewegen sich herum, - Sie haben Spaß.
# Image 432: wir in diesem einzigartige Elemente entwerfen.
# Image 3687: - wollte die Gesundheit von Krankheit wiederherstellen.
# Image 4812: und es dauerte 18 Monate.
# Image 6000: - das ist faszinierend.
# Image 5280: Er ist mein Großvater.
# Image 1206: sie werden in der Regel von der dritten Person vergessen.
# Image 4699: um, meine Marke?
# Image 2608: Es atmet dieses Uran, während es sich bewegt, also ist es irgendwie wie eine Kerze.
# Image 4478: und dann passierten einige sehr lustige Dinge.
# Image 6413: "Erinnerst du dich an den Patienten, den du nach Hause geschickt hast?"
# Image 2791: Vielen Dank.
# Image 5308: zwei Paar Strümpfe für die Schule, die jeweils die Löcher des anderen verbergen.
# Image 4376: Du musst nur um den Block herumgehen, um es als eine Erscheinung zu sehen.
# Image 12: Die Ethnosphäre ist das große Erbe der Menschheit.
# Image 2624: das ist super wichtig.
# Image 2619: Für 2050 haben Sie viele Leute über diese 80-Prozent-Reduzierung gehört.
# Image 4473: - - wollen Ihnen sagen, wie wir das herausgefunden haben.
# Image 2476: Nun, ich denke, Nummer eins S! Neugier.
# Image 4164: und dann bewegte sich jeder nach unten.
# Image 6376: und es funktionierte für eine Weile, bis – 4 mich mit mrs drucker traf.
# Image 3682: sie schaut ihn an und sagt, "ich bin hier für super sex. 1
# Image 6019: Wir mögen es nicht, über unsere Geschichte zu sprechen.
# Image 5288: Es war ihr unvorstellbar, dass sie nicht erfolgreich sein würde.
# Image 6082: und glauben eigentlich, dass die Ted-Community mutiger sein muss.
# Image 3719: Es kostete 2,7 Milliarden Dollar.
# Image 2648: Dies ist ein wichtiger Wunsch, aber es ist einer - denken wir, dass wir erreichen können.
# Image 5671: Was ist das neue Land, in das die Welt sich bewegt?
# Image 5757: Je mehr es sich ändert, desto schneller ändert es sich.
# Image 1445: Phosphor kann jedoch nicht ersetzt werden.
# Image 6196: und das alte Zeitungswort, "wenn es blutet, führt es, S! sehr wahr.
# Image 1928: Ich habe 0 Projekte mitgebracht, die ich gerne vorstellen möchte.
#
# Translations for LLaMA:
# Image 4136: in einer bestimmten Weise, ist es fast so, wie das alte Traum von Michelangelo. Spanish: en una determinada forma, es
# Image 4105: SO obviously dies S! nicht alle zurück in meinen kleinen Rucksack passen. French: SO obviously ce S! ne pas aller rentrer dans
# Image 1614: in dieser Weise ist jedes Konzert ein einzigartiges Konzert. French: de cette façon, chaque concert est un concert
# Image 5569: Diese ist die Zentrale Verwaltung für die Dienstleistungen und Informationen. French: Cette est la ligne de téléphone pour les services
# Image 2019: die Spinnreserven haben mindestens zehn Sekunden Zeit, um die Netzwerk zu stabilisieren. Spanish: los reserv
# Image 2567: wer wird es sein? French: qui va-t-il y faire? Spanish: ¿quién va a ir? Russian: кем будет удел
# Image 2315: ich werde mich für die Regierung entscheiden. Spanish: voy a elegir a la gobernanza. French: je vais choisir la gouver
# Image 846: Hier sind noch ein paar Leute, die es ausprobieren. French: Voilà, voilà, voilà, voil
# Image 1015: Was ist mit den archäologischen Modellen? French: Qu'est-ce que les modèles archéologiques? Spanish: ¿Qué son
# Image 4246: das kann, wir wollen es für die Gestaltung und die Arbeit mit einem Symbol verwenden. Spanish: esta puede, queremos usarlo para diseñar
# Image 1136: und das ist geschehen mir diese letzten sechs Monate. French: et c'est arrivé à moi ces dernières six mois. Spanish
# Image 4126: Wenn wir die Städte festlegen, ist es wirklich ein großes Problem. French: Si nous fixons des villes, c'est vraiment
# Image 6048: du weißt, wir müssen glauben, dass wir alles nicht gesehen haben. Spanish: tú sabes, finalmente, todos debemos
# Image 4734: der nächste: das war das beste Tag ever. Spanish: el siguiente: este fue el mejor día ever. French: le prochain: c
# Image 4737: - wie Dinge, die sich unterscheiden. French: - comme des choses qui se distinguent. Spanish: - como cosas que se dist
# Image 4149: hier seht ihr die Stadt. French: voici la ville. Spanish: aquí ves la ciudad. Italian: qui siamo la città. Portuguese
# Image 5530: das ist ein kleines App. French: c'est un petit app. Spanish: es un pequeño app. Italian: è un piccolo app
# Image 3445: sie spielten für 18 Jahre Dicke, wir spielen für 16 Jahre. French: ils jouent des jeux de dés pendant 18
# Image 4929: und dann hier ist ein wirklich, wirklich großes Bild der kleinen Stücke Metall. Spanish: y luego aquí está un realmente grande, realmente
# Image 5133: du weißt, ihr habt euch schon gefragt, oder? French: vous savez, vous avez déjà posé la question, ou
# Image 2283: danke. French: merci. Spanish: gracias. Chinese: (, ) (, ) (, ) (, ) (, ) (
# Image 4099: Es gibt keinen Grund, warum wir hier in diesem Publikum stehen. Spanish: No hay excusa para ninguno de nosotros aquí en este
# Image 6690: es ist eine Frage der Freiheit gegen die Kontrolle. Spanish: es es una cuestión de libertad contra la control. French
# Image 542: Wir beschädigten etwa t50 der Magnetstangen. French: Nous avons endommagé environ t50 des magnétomagnés
# Image 669: - schreibe ich ein Lied, das ich jetzt schreiben kann, - - schreibe ich ein Lied, das ich jetzt sch
# Image 4698: wie würden Sie Ihre Marke beschreiben? Spanish: ¿Cómo describiría su marca? French: comment décrire votre marque? Italian:
# Image 1553: wir können das machen. French: nous pouvons le faire. Spanish: podemos hacerlo. Italian: possiamo farelo. Portuguese: podemos
# Image 1301: Jeder war bereits ein Stück Kuchen gegessen. French: Chaque personne avait déjà un peu de gâteau. Spanish: Cada
# Image 712: weder zufrieden sein noch wütend sein. French: ne pas être déterminé. Spanish: no estar determinado. Italian
# Image 1371: dass es nicht zu viele von uns gibt, wir sind einfach zu dumm, du siehst? Spanish: que no hay muchos de nosotros,
# Image 2971: ich muss sagen, ich bin nicht damit einverstanden. French: je dois dire que je ne comprends pas. Spanish: no puedo decir que
# Image 6405: undi - ging zurück zu meiner Arbeit an den Wäldern. Spanish: yandi - regresó a mi trabajo en las zonas
# Image 2066: also, ich habe gerade begonnen, zu spielen. French: et, j'ai juste commencé à jouer. Spanish: y, solo empezé
# Image 6469: jetzt 5 beides, ich habe sie nicht nach Hause geschickt und - denke nicht, es gäbe einen Spalt in ihrem
# Image 3025: und dann werde ich erklären, warum  erklärt es. French: et puis je vais expliquer pourquoi  explique ce. Spanish:
# Image 504: Sonnenlicht und Kohlendioxid ist eine Methode... Spanish: Sol y CO2 es una forma... French: Le soleil et le
# Image 5901: sie war die Tochter von Menschen, die tatsächlich gefangen genommen wurden. Spanish: ella era la hija de personas que er
# Image 4295: So ist es jetzt vollständig gehemmt. French: Il est désormais complètement immobilisé. Spanish: Es está ahora completamente
# Image 1114: das ist ein Spiel für außerhalb. French: c'est un jeu pour l'extérieur. Spanish: es un juego para el exterior.
# Image 331: dritte: Erhöhung der Erwartungen. French: troisième: élevé de l'attente. Spanish: ter
# Image 4557: das ist die Folge, die wir haben müssen. French: c'est la conséquence que nous avons à faire. Spanish: es la consec
# Image 5689: und diejenigen, die so waren, begannen zu sicheln und zu trennen. Spanish: y aquellos que eran así comenz
# Image 5226: es wird in diesem Jahr über 200 Millionen Mal gesehen. French: il a été vu il y a environ 200 millions de fois. Spanish
# Image 9: und dies ist eine Idee, wenn du darüber nachdenkst, kann dir nur Hoffnung einbringen. French: et ceci est
# Image 3402: es gibt einen Wirtschaftsingenieur namens Edward Castronova. Spanish: hay un economista llamado Edward Castronova.
# Image 5906: und sie würde mich so fest drücken - - konnte ich kaum atmen und dann würde sie mich loslassen. Spanish: y ella me daría
# Image 5961: und diese waren die Dinge, die sie denken, dass wir zu committen sollten. Spanish: y estos fueron las cosas que pensaba que
# Image 5599: es verbindet diese beiden Menschen. French: il a rejoint ces deux personnes. Spanish: se ha unido a estos dos hombres. Italian
# Image 5485: und wir entwickelten ein iPad-App. Spanish: y construimos una aplicación para iPad. French: et nous avons construit une application
# Image 3533: es ist Teil unseres Lebens. French: c'est une partie de notre vie. Spanish: es una parte de nuestra vida. Italian: è una
# Image 2343: Ich -  wuchs auf einer stetigen Ernährung von Science fiction auf. Spanish: I -  creció en una dieta const
# Image 4637: sie wollten absolut nichts mit diesem Projekt zu tun haben. French: ils voulaient absolument rien de faire avec ce projet. Spanish: ellos
# Image 1411: Siehst du? Spanish: Vejas? French: Tu vois? Italian: Vedi? Portuguese: Vejas? Dutch: Ziet u
# Image 4449: mehrere Monate später, war ich an einer Aufführung meiner Tochter - erstgraderin, nicht viel künstlerische Talente
# Image 2886: jetzt, / verstehe ich. French: maintenant, / comprends-tu. Spanish: ahora, / entiendo. Italian: ora,
# Image 4714: in meinem verwarfen kleinen Industrie, das ist mein Markenname. Spanish: en mi pequeño industria, que es mi marca.
# Image 5917: und - würde sie ansehen und ich würde lächeln, aber sie war sehr ernst. Spanish: y - vería a ella y yo
# Image 3821: So geh steh in der Spiel. French: So s'assiede-t-il dans le jeu. Spanish: ¡Esto es un juego
# Image 27: lass uns kogi machen. 2I French: laissez-moi faire kogi. 3I Spanish: haz que haga k
# Image 1778: weil wir uns nicht leisten können, dieses Lügen zu leben. French: car nous ne pouvons pas vivre notre vie sans cela.
# Image 1027: wie viele Türen hat das Haus, in dem du lebst? French: combien de portes a-t-il? Spanish: cuánt
# Image 2758: sie führen das Prozess, sie verstehen das Prozess. Spanish: ellos manejan el proceso, ellos entienden el proceso
# Image 1720: und auch etwas, was sie heute in ihren Gedanken machen würden. Spanish: y también algo que ellos hacerán hoy en sus pensamientos.
# Image 5572: SO Scotts bekommt diese Anruf. French: SO Scotts obtient ce appel. Spanish: SO Scotts recibe este llamado
# Image 1822: wie die Menschen die Seele denken. French: comment les gens pensent-ils la âme? Spanish: ¿cómo piensan
# Image 2784: es gibt Schritt-für-Schritt-Anleitungen auf dieser. French: il y a des étapes pour suivre sur cette.
# Image 4696: Ich brauche, um mit dem Mann am Straßenrand zu sprechen, die Menschen, die mir ähnlich sind, die normalen J
# Image 305: und 11 denkt, dass die Welt so aussieht. French: et 11 pense que la planète ressemble à ça. Spanish
# Image 4830: du gehst um, du hast Spaß. French: tu es en mouvement, tu as du plaisir. Spanish: tú vas de un lugar
# Image 432: wir bauen diese Elemente in uns ein. French: nous créons ces éléments dans nous. Spanish: creamos estos elementos en nosotros.
# Image 3687: - wollte die Gesundheit wiederherstellen. French: - voulait restaurer la santé. Spanish: - quería restaurar la salud
# Image 4812: und es dauerte 18 Monate. French: et il a fallu 18 mois. Spanish: y tardó 18 meses. Italian
# Image 6000: - ist faszinierend. French: - est fascinant. Spanish: - es fascinante. Italian: - è fascinante
# Image 5280: er ist mein Opa. French: il est mon grand-père. Spanish: es mi abuelo. Italian: è mio nonno.
# Image 1206: sie werden normalerweise im dritten Term vergessen. French: ils sont généralement oubliés dans le troisième terme.
# Image 4699: wie, meine Marke? Spanish: ¿cómo, mi marca? French: comment, ma marque? Italian: come, la mia marca?
# Image 2608: es atmet dieses Uran wie es geht, so ist es wie ein Leuchter. Spanish: es respira este uranio como se va,
# Image 4478: und dann kam etwas ganz lustig. French: et puis tout ce qui était possible fut fait. Spanish: y luego todo lo que era posible fue
# Image 6413: "wir wissen nicht, ob du den Patienten erinnern kannst, den du zu Hause gebracht hast." French: "nous
# Image 2791: danke sehr. French: merci beaucoup. Spanish: gracias mucho. Italian: grazie molto. Portuguese: obrigado(a). Russian: благ
# Image 5308: zwei Paare Schuhcreme für die Schule, jede um den anderen zu verstecken. French: Deux paquets de sous-
# Image 4376: du hast einfach nur um die Ecke herum gesehen, weil es ein Eingebettetes ist. French: tu as juste vu ce
# Image 12: die ethnosphäre ist die große Erbe der Menschheit. French: l'ethnosphère est le grand héritage de
# Image 2624: das ist super wichtig. Spanish: que es super importante. French: c'est super important. Italian: è super importante. Portuguese: que é super
# Image 2619: für 2050 haben viele Menschen darüber gesprochen, wie 80 Prozent reduziert werden kann. Spanish: para 2050, muchos
# Image 4473: - - wollen Sie wissen, wie wir es herausgefunden haben. French: - - veulent vous dire comment nous avons trouvé cela. Spanish
# Image 2476: Ich denke, dass Nummer eins S! Neugier. French: Je pense que le numéro un S! Curiosité. Spanish:
# Image 4164: und dann ging jeder in die Tiefe. French: et puis tout le monde se mit en bas. Spanish: y luego todos se bajaron.
# Image 6376: und es arbeitete für ein paar Monate, bis - 4 mit mrs. drucker traf.
# Image 3682: sie sieht ihn an und sagt, "ich bin hier für super sex." 2 Spanish: ella mira a él y dice, "estoy
# Image 6019: wir lieben es nicht, über unsere Geschichte zu sprechen. French: nous n'aimons pas à discuter de notre histoire. Spanish:
# Image 5288: es war unmöglich, dass sie es schaffen würde. French: c'était impossible qu'elle ne réussisse pas. Spanish: era impos
# Image 6082: und ich glaube wirklich, dass der ted community mehr Mut braucht.
# Image 3719: es kostete 2,7 Milliarden Dollar. French: il coûte 2,7 milliard de dollars. Spanish: cuesta
# Image 2648: das ist eine wichtige Wunsch, aber es ist eine - denken wir, dass wir erreichen können. Spanish: este es un deseo
# Image 5671: was ist das neue Land, das der Welt die Richtung gibt? French: qu'est-ce que ce nouveau pays que la planète nous donne?
# Image 5757: das mehr es sich ändert, desto schneller ändert es sich. French: le plus il se déforme, plus vite il
# Image 1445: aber phosphor wird nicht ersetzt werden können. French: mais le phosphore ne sera pas remplacé. Spanish: pero el fosf
# Image 6196: und das alte Zeitungssay, "wenn es blutet es führt, S! sehr wahr. French: et ce vieux
# Image 1928: ich habe ein Projekt mit 0 gewählt, das ich gerne mit dir teilen möchte. French: j'ai apporté un projet de
#
# Translations for M2M100:
# Image 4136: In gewisser Weise ist es fast wie der alte Traum von Michelangelo.
# Image 4105: So offensichtlich dieses S! nicht alle passen wieder ul meine winzige Koffer.
# Image 1614: Jedes Konzert ist ein anderes Konzert.
# Image 5569: Dies ist das Call Center für die Dienstleistungen und Informationslinie.
# Image 2019: Die Spinnreserve hat mindestens zehn Sekunden Zeit, um das Netzwerk stabil zu halten.
# Image 2567: Wer wird sich sicher sein?
# Image 2315: Ich werde weitermachen und eine Regierung auswählen.
# Image 846: Hier sind noch ein paar andere Leute, die es ausprobieren.
# Image 1015: Was sind archaische Modelle?
# Image 4246: Dies kann, u! unser Fall sein, wir wollen es für das Entwerfen und die Herstellung eines Symbols verwenden.
# Image 1136: Und das ist mir in den letzten sechs Monaten passiert.
# Image 4126: Wenn wir Städte reparieren, ist es eigentlich eine große Sache.
# Image 6048: Schließlich müssen wir alle an Dinge glauben, die wir nicht gesehen haben.
# Image 4734: Nächster Beitrag: Dies war der beste Tag aller Zeiten
# Image 4737: Wie Dinge, die anders sind.
# Image 4149: Hier sehen Sie die Stadt.
# Image 5530: Dies ist eine bescheidene kleine App.
# Image 3445: Sie spielen seit 18 Jahren Würfelspiele, wir spielen seit 16 Jahren Warcraft.
# Image 4929: Und dann ist hier eine wirklich, wirklich große Nahaufnahme des kleinen Metallstücks.
# Image 5133: Sie wussten, dass es einen Trick gab, nicht Sie.
# Image 2283: Vielen Dank
# Image 4099: So gibt es keine Entschuldigung für jeden von uns hier in diesem Publikum.
# Image 6690: Es ist eine Frage der Freiheit gegen die Kontrolle.
# Image 542: So haben wir etwa t50 der Magnete beschädigt.
# Image 669: - Doil sieht aus wie - - kann jetzt ein: Song schreiben?
# Image 4698: Wie würden Sie Ihre Marke beschreiben?
# Image 1553: Wir können das tun.
# Image 1301: Jeder hatte schon früher einen Kuchen.
# Image 712: Seien Sie nicht verärgert.
# Image 1371: Das bedeutet, dass es nicht zu viele von uns gibt, wir sind einfach zu dumm, siehst du?
# Image 2971: Ich muss sagen, ich verstehe es nicht.
# Image 6405: andi - ging zurück zu meiner Arbeit an den Abteilungen.
# Image 2066: Dann begann Iris zu spielen.
# Image 6469: jetzt 5 beide Fälle, ich schickte sie nicht nach Hause und - glaube nicht, dass es eine Lücke ul ihre Pf
# Image 3025: Und dann werde ich erklären, warum ich es erklärt habe.
# Image 504: Sonnenlicht und CO2 sind eine Methode ...
# Image 5901: Sie war die Tochter von Menschen, die tatsächlich versklavt wurden.
# Image 4295: So ist die Versuchung nun vollständig gelähmt.
# Image 1114: Das ist ein Spiel für draußen.
# Image 331: Drittens: Die Eskalation der Erwartungen.
# Image 4557: Das ist die Konsequenz, mit der wir uns konfrontieren müssen.
# Image 5689: Und diejenigen, die so waren, begannen sich zu trennen und zu trennen.
# Image 5226: Es wurde in diesem Jahr fast 200 Millionen Mal gesehen.
# Image 9: Und dies ist eine Idee, wenn du darüber nachdenkst, kann dich nur mit Hoffnung füllen.
# Image 3402: Es gibt einen Ökonomen namens Edward Castronova.
# Image 5906: und sie würde mich so fest drücken - - konnte kaum atmen und dann ließ sie mich gehen.
# Image 5961: Und das waren die Dinge, an denen sie dachte, dass wir uns verpflichten mussten.
# Image 5599: Es verbindet diese beiden Menschen.
# Image 5485: Wir haben eine iPad App entwickelt.
# Image 3533: Es ist Teil unseres Lebens.
# Image 2343: Ich - wuchs auf einer stetigen Diät der Science-Fiction.
# Image 4637: Sie wollten mit diesem Projekt absolut nichts zu tun haben.
# Image 1411: Siehst du das?
# Image 4449: Etwa einen Monat später war ich bei einer Aufführung meiner Tochter - Erstklassiger, nicht viel künstlerisches Tal
# Image 2886: jetzt, / verstehe es.ich verstehe es.
# Image 4714: In meiner verdrehten kleinen Industrie, das ist meine Marke.
# Image 5917: und - würde sie ansehen und ich würde lächeln, aber sie war sehr ernst.
# Image 3821: So geti im Spiel.s retten die Schuhe.
# Image 27: Lasst uns es kogi machen. 1I
# Image 1778: Weil wir unser Leben nicht ohne diese Lüge leben können.
# Image 1027: Wie viele Türen hat das Haus, in dem Sie wohnen?
# Image 2758: Sie beherrschen den Prozess, sie verstehen den Prozess.
# Image 1720: Und was auch immer sie heute in ihren Köpfen haben.
# Image 5572: Scott bekommt diesen Anruf.
# Image 1822: So denken die Menschen, dass die Seele funktioniert.
# Image 2784: Hier gibt es Schritt für Schritt Anweisungen dazu.
# Image 4696: Ich muss mit dem Mann auf der Straße sprechen, die Leute, die wie ich sind, die normalen Joes.
# Image 305: und 11 glauben, dass es die Welt so macht.
# Image 4830: Sie bewegen sich herum - Sie haben Spaß.
# Image 432: Wir entwerfen hierzu einzigartige Elemente.
# Image 3687: - wollte Gesundheit aus Krankheit wiederherstellen.
# Image 4812: Und es dauerte 18 Monate.
# Image 6000: Das heißt, es ist faszinierend.
# Image 5280: Er ist mein Großvater.
# Image 1206: Sie werden in der Regel nach dem dritten Termin vergessen.
# Image 4699: Und mein Brand?
# Image 2608: Es atmet dieses Uran, während es geht, so ist es wie eine Kerze.
# Image 4478: Und dann passierten einige sehr lustige Dinge.
# Image 6413: "Erinnerst du dich an den Patienten, den du nach Hause geschickt hast?"
# Image 2791: Vielen Dank Dir sehr.
# Image 5308: zwei Paar Strümpfe für die Schule, jede die Löcher ul den anderen zu verbergen.
# Image 4376: Sie müssen nur um den Block herumlaufen, um ihn als Epiphany zu sehen.
# Image 12: Die Ethnosphäre ist das große Erbe der Menschheit.
# Image 2624: Das ist super wichtig.
# Image 2619: Für 2050 haben Sie viele Leute von dieser Reduzierung von 80 Prozent gehört.
# Image 4473: - - Ich möchte Ihnen sagen, wie wir das herausgefunden haben.
# Image 2476: Nun, ich denke Nummer eins S! Neugier.
# Image 4164: Dann zogen alle nach unten.
# Image 6376: und es funktionierte für eine Weile, bis - 4 traf Mrs. Drucker.
# Image 3682: sie schaut ihn an und sagt: "ich bin hier für super sex.
# Image 6019: Wir reden nicht gerne über unsere Geschichte.
# Image 5288: Es war ihr unvorstellbar, dass es ihr nicht gelingen würde.
# Image 6082: Und ich glaube wirklich, dass die Ted-Community mutiger sein muss.
# Image 3719: Das kostete 2,7 Milliarden Dollar.
# Image 2648: Dies ist ein wichtiger Wunsch, aber es ist eins - glauben wir, dass wir es erreichen können.
# Image 5671: Was ist dieser neue Staat, in den sich die Welt bewegt?
# Image 5757: Je mehr es sich ändert, desto schneller ändert es sich.
# Image 1445: Phosphor kann nicht ersetzt werden.
# Image 6196: Und die alte Zeitung sagte: "Wenn es blutet, führt es, S! sehr wahr.
# Image 1928: ich habe 0 Projekte mitgebracht, die ich Ihnen vorstellen möchte.

# %% [markdown]
# ## Evaluar los resultados de cada modelo

# %%
mt_eval.corpus_evaluate(to_json=False)
# Out:
# Engine: euroLLM
# BLEU:  18.18003738039132
# CHRF:  46.45867417167403
# TER:  61.117717003567186
#
# Engine: LLaMA
# BLEU:  5.341022860877584
# CHRF:  35.31867390001559
# TER:  182.04518430439953
#
# Engine: M2M100
# BLEU:  14.736277117603246
# CHRF:  44.553452976905994
# TER:  61.59334126040428
